# %%
import lxml
import re
import numpy as np
import pandas as pd

from bs4 import BeautifulSoup
from requests import get

# %%
url1 = "https://www.imdb.com/search/title/?title_type=feature&release_date=1996-03-29,2018-09-24&sort=num_votes,desc"

# %%
class IMDB(object):
	"""docstring for IMDB"""
	def __init__(self, url):
		super(IMDB, self).__init__()
		page = get(url)

		self.soup = BeautifulSoup(page.content, 'lxml')

	def articleTitle(self):
		return self.soup.find("h1", class_="header").text.replace("\n","")

	def bodyContent(self):
		content = self.soup.find(id="main")
		return content.find_all("div", class_="lister-item mode-advanced")

	def movieData(self):
		movieFrame = self.bodyContent()
		movieTitle = []
		movieDate = []
		movieRunTime = []
		movieGenre = []
		movieRating = []
		movieScore = []
		movieDescription = []
		movieDirector = []
		movieStars = []
		movieVotes = []
		movieGross = []
		for movie in movieFrame:
			movieFirstLine = movie.find("h3", class_="lister-item-header")
			movieTitle.append(movieFirstLine.find("a").text)
			movieDate.append(re.sub(r"[()]","", movieFirstLine.find_all("span")[-1].text))
			try:
				movieRunTime.append(movie.find("span", class_="runtime").text[:-4])
			except:
				movieRunTime.append(np.nan)
			movieGenre.append(movie.find("span", class_="genre").text.rstrip().replace("\n","").split(","))
			try:
				movieRating.append(movie.find("strong").text)
			except:
				movieRating.append(np.nan)
			try:
				movieScore.append(movie.find("span", class_="metascore favorable").text.rstrip())
			except:
				movieScore.append(np.nan)
			movieDescription.append(movie.find_all("p", class_="text-muted")[-1].text.lstrip())
			movieCast = movie.find("p", class_="")

			try:
				casts = movieCast.text.replace("\n","").split('|')
				casts = [x.strip() for x in casts]
				casts = [casts[i].replace(j, "") for i,j in enumerate(["Director:", "Stars:"])]
				movieDirector.append(casts[0])
				movieStars.append([x.strip() for x in casts[1].split(",")])
			except:
				casts = movieCast.text.replace("\n","").strip()
				movieDirector.append(np.nan)
				movieStars.append([x.strip() for x in casts.split(",")])

			movieNumbers = movie.find_all("span", attrs={"name": "nv"})

			if len(movieNumbers) == 2:
				movieVotes.append(movieNumbers[0].text)
				movieGross.append(movieNumbers[1].text)
			elif len(movieNumbers) == 1:
				movieVotes.append(movieNumbers[0].text)
				movieGross.append(np.nan)
			else:
				movieVotes.append(np.nan)
				movieGross.append(np.nan)

		movieData = [movieTitle, movieDate, movieRunTime, movieGenre, movieRating, movieScore, movieDescription,
							movieDirector, movieStars, movieVotes, movieGross]
		return movieData

# %%
if __name__ == '__main__':
	site1 = IMDB(url1)
	print("Subject: ", site1.articleTitle())
	data = site1.movieData()
	for i in range(len(data)):
		print(data[i][:]) #Print the data
# Out:
# Subject:  Feature Film,Released between 1996-03-29 and 2018-09-24(Sorted by Number of Votes Descending)
# ['The Dark Knight', 'Inception', 'Fight Club', 'The Matrix', 'The Lord of the Rings: The Fellowship of the Ring', 'The Lord of the Rings: The Return of the King', 'The Dark Knight Rises', 'The Lord of the Rings: The Two Towers', 'Interstellar', 'Django Unchained', 'Gladiator', 'Batman Begins', 'The Avengers', 'Inglourious Basterds', 'Saving Private Ryan', 'The Departed', 'The Prestige', 'The Wolf of Wall Street', 'The Green Mile', 'Avatar', 'Memento', 'Shutter Island', 'American Beauty', 'Guardians of the Galaxy', 'Titanic', 'American History X', 'V for Vendetta', 'Pirates of the Caribbean: The Curse of the Black Pearl', 
# ['9.0', '8.8', '8.8', '8.7', '8.8', '8.9', '8.4', '8.7', '8.6', '8.4', '8.5', '8.2', '8.0', '8.3', '8.6', '8.5', '8.5', '8.2', '8.6', '7.8', '8.4', '8.1', '8.3', '8.0', '7.8', '8.5', '8.2', '8.0', '8.1', '8.4', '8.1', '7.9', '8.2', '8.1', '8.1', '8.3', '8.0', '8.1', '7.9', '8.3', '7.2', '8.1', '8.1', '8.2', '8.1', '8.0', '8.4', '8.0', '8.3', '7.7']
# ['84', '74', '66', '73', '92', '94', '78', '87', '74', '81', '67', '70', '69', '69', '91', '85', '66', '75', '61', '83', '80', '63', '84', '76', '75', '62', '62', '63', '69', '95', '90', '79', '88', '90', '64', '89', '65', '90', '80', '70', '68', '79', '91', '72', '75', '79', '68', '84', nan, '96']
# ['When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.', 'A thief who steals corporate secrets through the use of dream-sharing technology is given the inverse task of planting an idea into the mind of a C.E.O.', 'An insomniac office worker and a devil-may-care soapmaker form an underground fight club that evolves into something much, much more.', 'A computer hacker learns from mysterious rebels about the true nature of his reality and his role in the war against its controllers.', 'A meek Hobbit from the Shire and eight companions set out on a journey to destroy the powerful One Ring and save Middle-earth from the Dark Lord Sauron.', "Gandalf and Aragorn lead the World of Men against Sauron's army to draw his gaze from Frodo and Sam as they approach Mount Doom with the One Ring.", "Eight years after the Joker's reign of anarchy, Batman, with the help of the enigmatic Catwoman, is forced from his exile to save Gotham City from the brutal guerrilla terrorist Bane.", "While Frodo and Sam edge closer to Mordor with the help of the shifty Gollum, the divided fellowship makes a stand against Sauron's new ally, Saruman, and his hordes of Isengard.", "A team of explorers travel through a wormhole in space in an attempt to ensure humanity's survival.", 'With the help of a German bounty hunter, a freed slave sets out to rescue his wife from a brutal Mississippi plantation owner.', 'A former Roman General sets out to exact vengeance against the corrupt emperor who murdered his family and sent him into slavery.', 'After training with his mentor, Batman begins his fight to free crime-ridden Gotham City from corruption.', "Earth's mightiest heroes must come together and learn to fight as a team if they are going to stop the mischievous Loki and his alien army from enslaving humanity.", "In Nazi-occupied France during World War II, a plan to assassinate Nazi leaders by a group of Jewish U.S. soldiers coincides with a theatre owner's vengeful plans for the same.", 'Following the Normandy Landings, a group of U.S. soldiers go behind enemy lines to retrieve a paratrooper whose brothers have been killed in action.', 'An undercover cop and a mole in the police attempt to identify each other while infiltrating an Irish gang in South Boston.', 'After a tragic accident, two stage magicians engage in a battle to create the ultimate illusion while sacrificing everything they have to outwit each other.', 'Based on the true story of Jordan Belfort, from his rise to a wealthy stock-broker living the high life to his fall involving crime, corruption and the federal government.', 'The lives of guards on Death Row are affected by one of their charges: a black man accused of child murder and rape, yet who has a mysterious gift.', 'A paraplegic Marine dispatched to the moon Pandora on a unique mission becomes torn between following his orders and protecting the world he feels is his home.', "A man with short-term memory loss attempts to track down his wife's murderer.", 'In 1954, a U.S. Marshal investigates the disappearance of a murderer who escaped from a hospital for the criminally insane.', "A sexually frustrated suburban father has a mid-life crisis after becoming infatuated with his daughter's best friend.", 'A group of intergalactic criminals must pull together to stop a fanatical warrior with plans to purge the universe.', 'A seventeen-year-old aristocrat falls in love with a kind but poor artist aboard the luxurious, ill-fated R.M.S. Titanic.', 'A former neo-nazi skinhead tries to prevent his younger brother from going down the same wrong path that he did.', 'In a future British tyranny, a shadowy freedom fighter, known only by the alias of "V", plots to overthrow it with the help of a young woman.', 'Blacksmith Will Turner teams up with eccentric pirate "Captain" Jack Sparrow to save his love, the governor\'s daug ...
# ['Christopher Nolan', 'Christopher Nolan', 'David Fincher', 'Directors:Lana Wachowski, Lilly Wachowski', 'Peter Jackson', 'Peter Jackson', 'Christopher Nolan', 'Peter Jackson', 'Christopher Nolan', 'Quentin Tarantino', 'Ridley Scott', 'Christopher Nolan', 'Joss Whedon', 'Quentin Tarantino', 'Steven Spielberg', 'Martin Scorsese', 'Christopher Nolan', 'Martin Scorsese', 'Frank Darabont', 'James Cameron', 'Christopher Nolan', 'Martin Scorsese', 'Sam Mendes', 'James Gunn', 'James Cameron', 'Tony Kaye', 'James McTeigue', 'Gore Verbinski', 'Quentin Tarantino', 'Andrew Stanton', 'Directors:Andrew Stanton, Lee Unkrich', 'Jon Favreau', 'Directors:Pete Docter, Bob Peterson', 'Peter Weir', 'M. Night Shyamalan', 'Michel Gondry', 'Tim Miller', 'George Miller', 'J.J. Abrams', 'Gus Van Sant', 'Gary Ross', 'David Fincher', 'Directors:Ethan Coen, Joel Coen', 'Ron Howard', 'Steven Spielberg', 'Directors:Pete Docter, David Silverman, Lee Unkrich', 'Directors:Anthony Russo, Joe Russo', 'Directors:Danny Boyle, Loveleen Tandan', 'Guy Ritchie', 'Alfonso Cuarón']
# [['Christian Bale', 'Heath Ledger', 'Aaron Eckhart', 'Michael Caine'], ['Leonardo DiCaprio', 'Joseph Gordon-Levitt', 'Ellen Page', 'Ken Watanabe'], ['Brad Pitt', 'Edward Norton', 'Meat Loaf', 'Zach Grenier'], ['Keanu Reeves', 'Laurence Fishburne', 'Carrie-Anne Moss', 'Hugo Weaving'], ['Elijah Wood', 'Ian McKellen', 'Orlando Bloom', 'Sean Bean'], ['Elijah Wood', 'Viggo Mortensen', 'Ian McKellen', 'Orlando Bloom'], ['Christian Bale', 'Tom Hardy', 'Anne Hathaway', 'Gary Oldman'], ['Elijah Wood', 'Ian McKellen', 'Viggo Mortensen', 'Orlando Bloom'], ['Matthew McConaughey', 'Anne Hathaway', 'Jessica Chastain', 'Mackenzie Foy'], ['Jamie Foxx', 'Christoph Waltz', 'Leonardo DiCaprio', 'Kerry Washington'], ['Russell Crowe', 'Joaquin Phoenix', 'Connie Nielsen', 'Oliver Reed'], ['Christian Bale', 'Michael Caine', 'Ken Watanabe', 'Liam Nee
# ['2,224,414', '1,981,548', '1,794,361', '1,619,665', '1,609,082', '1,593,769', '1,470,261', '1,440,109', '1,430,687', '1,306,968', '1,297,616', '1,268,973', '1,236,013', '1,219,295', '1,194,122', '1,150,711', '1,144,424', '1,128,011', '1,101,610', '1,096,090', '1,090,227', '1,086,257', '1,043,031', '1,017,369', '1,017,183', '1,007,398', '1,002,886', '997,229', '970,377', '967,870', '922,035', '915,618', '904,995', '900,935', '888,870', '882,435', '876,034', '847,926', '841,201', '830,077', '826,470', '825,382', '823,067', '821,660', '790,781', '789,731', '784,677', '782,634', '761,617', '751,266']
# ['$534.86M', '$292.58M', '$37.03M', '$171.48M', '$315.54M', '$377.85M', '$448.14M', '$342.55M', '$188.02M', '$162.81M', '$187.71M', '$206.85M', '$623.28M', '$120.54M', '$216.54M', '$132.38M', '$53.09M', '$116.90M', '$136.80M', '$760.51M', '$25.54M', '$128.01M', '$130.10M', '$333.18M', '$659.33M', '$6.72M', '$70.51M', '$305.41M', '$70.10M', '$223.81M', '$380.84M', '$318.41M', '$293.00M', '$125.62M', '$293.51M', '$34.40M', '$363.07M', '$154.06M', '$936.66M', '$138.43M', '$408.01M', '$167.77M', '$74.28M', '$170.74M', '$164.62M', '$289.92M', '$678.82M', '$141.32M', '$30.33M', '$274.09M']

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-304fa4ce4ebd> in <module>
# ----> 1 data.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %%
data1 = pd.DataFrame(data)

# %%
data1.head()
# Out:
#                          0                              1           2   \
# 0           The Dark Knight                      Inception  Fight Club
# 1                      2008                           2010        1999
# 2                       152                            148         139
# 3  [Action,  Crime,  Drama]  [Action,  Adventure,  Sci-Fi]     [Drama]
# 4                       9.0                            8.8         8.8
#
#                   3                                                  4   \
# 0         The Matrix  The Lord of the Rings: The Fellowship of the Ring
# 1               1999                                               2001
# 2                136                                                178
# 3  [Action,  Sci-Fi]                       [Action,  Adventure,  Drama]
# 4                8.7                                                8.8
#
#                                               5                      6   \
# 0  The Lord of the Rings: The Return of the King  The Dark Knight Rises
# 1                                           2003                   2012
# 2                                            201                    164
# 3                  [Adventure,  Drama,  Fantasy]   [Action,  Adventure]
# 4                                            8.9                    8.4
#
#                                       7                             8   \
# 0  The Lord of the Rings: The Two Towers                  Interstellar
# 1                                   2002                          2014
# 2                                    179                           169
# 3          [Adventure,  Drama,  Fantasy]  [Adventure,  Drama,  Sci-Fi]
# 4                                    8.7                           8.6
#
#                   9   ...                             40  \
# 0   Django Unchained  ...               The Hunger Games
# 1               2012  ...                           2012
# 2                165  ...                            142
# 3  [Drama,  Western]  ...  [Action,  Adventure,  Sci-Fi]
# 4                8.4  ...                            7.2
#
#                              41                          42  \
# 0                     Gone Girl      No Country for Old Men
# 1                          2014                        2007
# 2                           149                         122
# 3  [Drama,  Mystery,  Thriller]  [Crime,  Drama,  Thriller]
# 4                           8.1                         8.1
#
#                     43                           44  \
# 0     A Beautiful Mind          Catch Me If You Can
# 1                 2001                         2002
# 2                  135                          141
# 3  [Biography,  Drama]  [Biography,  Crime,  Drama]
# 4                  8.2                          8.1
#
#                                  45                             46  \
# 0                    Monsters, Inc.         Avengers: Infinity War
# 1                              2001                           2018
# 2                                92                            149
# 3  [Animation,  Adventure,  Comedy]  [Action,  Adventure,  Sci-Fi]
# 4                               8.0                            8.4
#
#                     47                48                           49
# 0  Slumdog Millionaire            Snatch                      Gravity
# 1                 2008              2000                         2013
# 2                  120               104                           91
# 3    [Drama,  Romance]  [Comedy,  Crime]  [Drama,  Sci-Fi,  Thriller]
# 4                  8.0               8.3                          7.7
#
# [5 rows x 50 columns]

# %%
data1 = data1.transpose()
data1.head()
# Out:
#                                                    0     1    2  \
# 0                                    The Dark Knight  2008  152
# 1                                          Inception  2010  148
# 2                                         Fight Club  1999  139
# 3                                         The Matrix  1999  136
# 4  The Lord of the Rings: The Fellowship of the Ring  2001  178
#
#                                3    4   5  \
# 0       [Action,  Crime,  Drama]  9.0  84
# 1  [Action,  Adventure,  Sci-Fi]  8.8  74
# 2                        [Drama]  8.8  66
# 3              [Action,  Sci-Fi]  8.7  73
# 4   [Action,  Adventure,  Drama]  8.8  92
#
#                                                    6  \
# 0  When the menace known as the Joker wreaks havo...
# 1  A thief who steals corporate secrets through t...
# 2  An insomniac office worker and a devil-may-car...
# 3  A computer hacker learns from mysterious rebel...
# 4  A meek Hobbit from the Shire and eight compani...
#
#                                            7  \
# 0                          Christopher Nolan
# 1                          Christopher Nolan
# 2                              David Fincher
# 3  Directors:Lana Wachowski, Lilly Wachowski
# 4                              Peter Jackson
#
#                                                    8          9        10
# 0  [Christian Bale, Heath Ledger, Aaron Eckhart, ...  2,224,414  $534.86M
# 1  [Leonardo DiCaprio, Joseph Gordon-Levitt, Elle...  1,981,548  $292.58M
# 2  [Brad Pitt, Edward Norton, Meat Loaf, Zach Gre...  1,794,361   $37.03M
# 3  [Keanu Reeves, Laurence Fishburne, Carrie-Anne...  1,619,665  $171.48M
# 4  [Elijah Wood, Ian McKellen, Orlando Bloom, Sea...  1,609,082  $315.54M

# %%
data1.columns = ['Title', 'Year', 'Runtime', 'Genre', 'Rating', 'Score', 'Description', 'Director', 'Actors', 'Votes', 'Gross']
data1.head()
# Out:
#                                                Title  Year Runtime  \
# 0                                    The Dark Knight  2008     152
# 1                                          Inception  2010     148
# 2                                         Fight Club  1999     139
# 3                                         The Matrix  1999     136
# 4  The Lord of the Rings: The Fellowship of the Ring  2001     178
#
#                            Genre Rating Score  \
# 0       [Action,  Crime,  Drama]    9.0    84
# 1  [Action,  Adventure,  Sci-Fi]    8.8    74
# 2                        [Drama]    8.8    66
# 3              [Action,  Sci-Fi]    8.7    73
# 4   [Action,  Adventure,  Drama]    8.8    92
#
#                                          Description  \
# 0  When the menace known as the Joker wreaks havo...
# 1  A thief who steals corporate secrets through t...
# 2  An insomniac office worker and a devil-may-car...
# 3  A computer hacker learns from mysterious rebel...
# 4  A meek Hobbit from the Shire and eight compani...
#
#                                     Director  \
# 0                          Christopher Nolan
# 1                          Christopher Nolan
# 2                              David Fincher
# 3  Directors:Lana Wachowski, Lilly Wachowski
# 4                              Peter Jackson
#
#                                               Actors      Votes     Gross
# 0  [Christian Bale, Heath Ledger, Aaron Eckhart, ...  2,224,414  $534.86M
# 1  [Leonardo DiCaprio, Joseph Gordon-Levitt, Elle...  1,981,548  $292.58M
# 2  [Brad Pitt, Edward Norton, Meat Loaf, Zach Gre...  1,794,361   $37.03M
# 3  [Keanu Reeves, Laurence Fishburne, Carrie-Anne...  1,619,665  $171.48M
# 4  [Elijah Wood, Ian McKellen, Orlando Bloom, Sea...  1,609,082  $315.54M
